# %% [markdown]
# # Bibliotecas Utilizadas:

# %%
import pandas as pd
import folium as fl
from folium import plugins
import requests
import json

# %% [markdown]
# # Dataframe

# %% [markdown]
# ## Leitura das Planilhas:

# %%
# URL das planilhas:
# Planilha de Sapucaia
sheet_url1 = "https://docs.google.com/spreadsheets/d/1HeFq3PTkunMfmencOt5grV3ADZ9sBJM-boqpGpbuymM/export?format=csv"

# Planilha de Anta
sheet_url2 = "https://docs.google.com/spreadsheets/d/1Q3JsL_9LOPb9_QKsKcvoVGrwR4MBWYBBCNplrxE957o/export?format=csv"

# Planilha de Aparecida
sheet_url3 = "https://docs.google.com/spreadsheets/d/1C64cDoJcD9r5sGzUMJAMyH8ILSPwzS5hTKwtGABtdkk/export?format=csv"

# Planilha do Distrito
sheet_url4 = "https://docs.google.com/spreadsheets/d/1rNR-X43WWxtAs9O0_5yCVeTvmInSowLxPq69U6i6DGE/export?format=csv"

# Leitura com o Pandas
sapucaia = pd.read_csv(sheet_url1)
sapucaia.name = 'sapucaia'

anta = pd.read_csv(sheet_url2)
anta.name = 'anta'

aparecida = pd.read_csv(sheet_url3)
aparecida.name = 'aparecida'

distrito = pd.read_csv(sheet_url4)
distrito.name = 'distrito'

sapucaia.info()
anta.info()
aparecida.info()
distrito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    102 non-null    float64
#  1   Longitude   102 non-null    float64
#  2   Logradouro  102 non-null    object
#  3   Obs         70 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 3.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    102 non-null    float64
#  1   Longitude   102 non-null    float64
#  2   Logradouro  102 non-null    object
#  3   Obs         68 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 3.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    64 non-null     float64
#  1   Longitude   64 non-null     float64
#  2   Logradouro  64 non-null     object
#  3   Obs         35 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    193 non-null    float64
#  1   Longitude   193 non-null    float64
#  2   Logradouro  193 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 6.3+ KB

# %%
# Visualização de Sapucaia:
sapucaia
# Out:
#       Latitude  Longitude                      Logradouro                Obs
# 0   -22.007424 -42.941037           Garagem dos caminhões   SAÍDA DA GARAGEM
# 1   -22.007330 -42.941422             Rua Oswaldo Melgaço               meio
# 2   -22.007565 -42.942233             Rua Oswaldo Melgaço            termina
# 3   -22.007936 -42.941919  Rua Heitor Marques de Carvalho             começa
# 4   -22.007348 -42.939631  Rua Heitor Marques de Carvalho  acho q acaba aqui
# ..         ...        ...                             ...                ...
# 97  -21.992547 -42.908848             Rua Manoel da Silva                NaN
# 98  -21.992190 -42.909048             Rua Manoel da Silva                NaN
# 99  -21.992069 -42.909024              Rua Rafael Langoni                NaN
# 100 -21.991134 -42.907078              Rua Rafael Langoni                NaN
# 101 -21.964027 -42.852742                Aterro Sanitário                NaN
#
# [102 rows x 4 columns]

# %%
# Visualização de Anta:
anta
# Out:
#       Latitude  Longitude                    Logradouro      Obs
# 0   -22.007424 -42.941037         Garagem dos caminhões   começa
# 1   -22.041284 -42.992389  Rua Pedro Fernandes da Silva  termina
# 2   -22.040849 -42.991806  Rua Pedro Fernandes da Silva   começa
# 3   -22.040015 -42.990792  Rua Pedro Fernandes da Silva  termina
# 4   -22.039789 -42.991229   Rua Virgínio Muniz de Jesus   começa
# ..         ...        ...                           ...      ...
# 97  -22.030878 -42.982263    Rua José Alves de Carvalho      NaN
# 98  -22.031602 -42.982014    Rua José Alves de Carvalho      NaN
# 99  -22.032368 -42.982959    Rua José Alves de Carvalho      NaN
# 100 -22.031820 -42.981846    Rua José Alves de Carvalho      NaN
# 101 -21.964027 -42.852742              Aterro Sanitário      NaN
#
# [102 rows x 4 columns]

# %%
# Visualização de Aparecida:
aparecida
# Out:
#      Latitude  Longitude                       Logradouro      Obs
# 0  -22.007424 -42.941037            Garagem dos caminhões      NaN
# 1  -22.034375 -42.779787         Av. Nicolau Tannus Soffe      NaN
# 2  -22.034609 -42.789097         Av. Nicolau Tannus Soffe   começa
# 3  -22.034258 -42.789486  Rua Alfredo Pereira de Carvalho  termina
# 4  -22.033855 -42.790459  Rua Alfredo Pereira de Carvalho  começa1
# ..        ...        ...                              ...      ...
# 59 -22.034548 -42.788377  Rua Alfredo Pereira de Carvalho      NaN
# 60 -22.034093 -42.786775         Av. Nicolau Tannus Soffe      NaN
# 61 -22.034242 -42.784226         Av. Nicolau Tannus Soffe      NaN
# 62 -22.034333 -42.779790         Av. Nicolau Tannus Soffe      NaN
# 63 -21.964027 -42.852742                 Aterro Sanitário      NaN
#
# [64 rows x 4 columns]

# %%
# Visualização do Distrito:
distrito
# Out:
#       Latitude  Longitude                       Logradouro
# 0   -22.007424 -42.941037            Garagem dos caminhões
# 1   -22.041284 -42.992389     Rua Pedro Fernandes da Silva
# 2          NaN        NaN                              NaN
# 3   -22.040015 -42.990792     Rua Pedro Fernandes da Silva
# 4   -22.039789 -42.991229      Rua Virgínio Muniz de Jesus
# ..         ...        ...                              ...
# 259 -22.034548 -42.788377  Rua Alfredo Pereira de Carvalho
# 260 -22.034093 -42.786775         Av. Nicolau Tannus Soffe
# 261 -22.034242 -42.784226         Av. Nicolau Tannus Soffe
# 262 -22.034333 -42.779790         Av. Nicolau Tannus Soffe
# 263 -21.964027 -42.852742                 Aterro Sanitário
#
# [264 rows x 3 columns]

# %% [markdown]
# ## Tratamento das Tabelas:

# %%
# Removendo a Coluna 'Obs'
sapucaia = sapucaia.drop('Obs', axis=1)
anta = anta.drop('Obs', axis=1)
aparecida = aparecida.drop('Obs', axis=1)

print(sapucaia.columns)
print(anta.columns)
print(aparecida.columns)
print(distrito.columns)
# Out:
# Index(['Latitude', 'Longitude', 'Logradouro'], dtype='object')
# Index(['Latitude', 'Longitude', 'Logradouro'], dtype='object')
# Index(['Latitude', 'Longitude', 'Logradouro'], dtype='object')
# Index(['Latitude', 'Longitude', 'Logradouro'], dtype='object')

# %%
# Excluindo linhas com NaN:
sapucaia = sapucaia.dropna()
anta = anta.dropna()
aparecida = aparecida.dropna()
distrito = distrito.dropna()

# %%
# Reordenando os indíces para que fiquem sequenciais
sapucaia = sapucaia.reset_index(drop=True)
anta = anta.reset_index(drop=True)
aparecida = aparecida.reset_index(drop=True)
distrito = distrito.reset_index(drop=True)

sapucaia.info()
anta.info()
aparecida.info()
distrito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    102 non-null    float64
#  1   Longitude   102 non-null    float64
#  2   Logradouro  102 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    102 non-null    float64
#  1   Longitude   102 non-null    float64
#  2   Logradouro  102 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    64 non-null     float64
#  1   Longitude   64 non-null     float64
#  2   Logradouro  64 non-null     object
# dtypes: float64(2), object(1)
# memory usage: 1.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    193 non-null    float64
#  1   Longitude   193 non-null    float64
#  2   Logradouro  193 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 4.6+ KB

# %%
# Excluindo a coluna 'index' e renomeando a 'level_0' como 'index'
# sapucaia = sapucaia.drop('index', axis = 1)
# sapucaia = sapucaia.rename(columns={'level_0': 'index'})

# anta = anta.drop('index', axis = 1)
# anta = anta.rename(columns={'level_0': 'index'})

# aparecida = aparecida.drop('index', axis = 1)
# aparecida = aparecida.rename(columns={'level_0': 'index'})

sapucaia.info()
anta.info()
aparecida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    102 non-null    float64
#  1   Longitude   102 non-null    float64
#  2   Logradouro  102 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    102 non-null    float64
#  1   Longitude   102 non-null    float64
#  2   Logradouro  102 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    64 non-null     float64
#  1   Longitude   64 non-null     float64
#  2   Logradouro  64 non-null     object
# dtypes: float64(2), object(1)
# memory usage: 1.6+ KB

# %%
# Definindo a coluna Longitude para o tipo 'float64'
sapucaia['Longitude']  = sapucaia['Longitude'].astype(float)
anta['Longitude']      = anta['Longitude'].astype(float)
aparecida['Longitude'] = aparecida['Longitude'].astype(float)
distrito['Longitude'] = distrito['Longitude'].astype(float)

sapucaia.info()
anta.info()
aparecida.info()
distrito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    102 non-null    float64
#  1   Longitude   102 non-null    float64
#  2   Logradouro  102 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    102 non-null    float64
#  1   Longitude   102 non-null    float64
#  2   Logradouro  102 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    64 non-null     float64
#  1   Longitude   64 non-null     float64
#  2   Logradouro  64 non-null     object
# dtypes: float64(2), object(1)
# memory usage: 1.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    193 non-null    float64
#  1   Longitude   193 non-null    float64
#  2   Logradouro  193 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 4.6+ KB

# %%
# Renomeando as colunas
sapucaia.rename(columns  = {'Latitude': 'latitude', 'Longitude': 'longitude', 'Logradouro': 'logradouro'}, inplace = True)
anta.rename(columns      = {'Latitude': 'latitude', 'Longitude': 'longitude', 'Logradouro': 'logradouro'}, inplace = True)
aparecida.rename(columns = {'Latitude': 'latitude', 'Longitude': 'longitude', 'Logradouro': 'logradouro'}, inplace = True)
distrito.rename(columns  = {'Latitude': 'latitude', 'Longitude': 'longitude', 'Logradouro': 'logradouro'}, inplace = True)

# %% [markdown]
# ## Visualização das Tabelas:

# %%
# Visualização de Sapucaia:
sapucaia
# Out:
#       latitude  longitude                      logradouro
# 0   -22.007424 -42.941037           Garagem dos caminhões
# 1   -22.007330 -42.941422             Rua Oswaldo Melgaço
# 2   -22.007565 -42.942233             Rua Oswaldo Melgaço
# 3   -22.007936 -42.941919  Rua Heitor Marques de Carvalho
# 4   -22.007348 -42.939631  Rua Heitor Marques de Carvalho
# ..         ...        ...                             ...
# 97  -21.992547 -42.908848             Rua Manoel da Silva
# 98  -21.992190 -42.909048             Rua Manoel da Silva
# 99  -21.992069 -42.909024              Rua Rafael Langoni
# 100 -21.991134 -42.907078              Rua Rafael Langoni
# 101 -21.964027 -42.852742                Aterro Sanitário
#
# [102 rows x 3 columns]

# %%
# Visualização de Anta:
anta
# Out:
#       latitude  longitude                    logradouro
# 0   -22.007424 -42.941037         Garagem dos caminhões
# 1   -22.041284 -42.992389  Rua Pedro Fernandes da Silva
# 2   -22.040849 -42.991806  Rua Pedro Fernandes da Silva
# 3   -22.040015 -42.990792  Rua Pedro Fernandes da Silva
# 4   -22.039789 -42.991229   Rua Virgínio Muniz de Jesus
# ..         ...        ...                           ...
# 97  -22.030878 -42.982263    Rua José Alves de Carvalho
# 98  -22.031602 -42.982014    Rua José Alves de Carvalho
# 99  -22.032368 -42.982959    Rua José Alves de Carvalho
# 100 -22.031820 -42.981846    Rua José Alves de Carvalho
# 101 -21.964027 -42.852742              Aterro Sanitário
#
# [102 rows x 3 columns]

# %%
# Visualização de Aparecida:
aparecida
# Out:
#      latitude  longitude                       logradouro
# 0  -22.007424 -42.941037            Garagem dos caminhões
# 1  -22.034375 -42.779787         Av. Nicolau Tannus Soffe
# 2  -22.034609 -42.789097         Av. Nicolau Tannus Soffe
# 3  -22.034258 -42.789486  Rua Alfredo Pereira de Carvalho
# 4  -22.033855 -42.790459  Rua Alfredo Pereira de Carvalho
# ..        ...        ...                              ...
# 59 -22.034548 -42.788377  Rua Alfredo Pereira de Carvalho
# 60 -22.034093 -42.786775         Av. Nicolau Tannus Soffe
# 61 -22.034242 -42.784226         Av. Nicolau Tannus Soffe
# 62 -22.034333 -42.779790         Av. Nicolau Tannus Soffe
# 63 -21.964027 -42.852742                 Aterro Sanitário
#
# [64 rows x 3 columns]

# %%
# Visualização do Distrito:
distrito
# Out:
#       latitude  longitude                       logradouro
# 0   -22.007424 -42.941037            Garagem dos caminhões
# 1   -22.041284 -42.992389     Rua Pedro Fernandes da Silva
# 2   -22.040015 -42.990792     Rua Pedro Fernandes da Silva
# 3   -22.039789 -42.991229      Rua Virgínio Muniz de Jesus
# 4   -22.040710 -42.992285      Rua Virgínio Muniz de Jesus
# ..         ...        ...                              ...
# 188 -22.034548 -42.788377  Rua Alfredo Pereira de Carvalho
# 189 -22.034093 -42.786775         Av. Nicolau Tannus Soffe
# 190 -22.034242 -42.784226         Av. Nicolau Tannus Soffe
# 191 -22.034333 -42.779790         Av. Nicolau Tannus Soffe
# 192 -21.964027 -42.852742                 Aterro Sanitário
#
# [193 rows x 3 columns]

# %%
# Dataframe para calcular a distância entre o aterro e a garagem sanitário:
garagem = pd.concat([sapucaia.iloc[[-1]], sapucaia.iloc[[0]]])
garagem
# Out:
#       latitude  longitude             logradouro
# 101 -21.964027 -42.852742       Aterro Sanitário
# 0   -22.007424 -42.941037  Garagem dos caminhões

# %% [markdown]
# # OSRM

# %% [markdown]
# ## Geração dos Mapas:

# %%
# Função para gerar os mapas:
def gerarMapas(data):

  # Criando os mapas com a Folium
  map = fl.Map(location=[data['Latitude'].mean(), data['Longitude'].mean()], zoom_start=14)

  # Adicionando os marcadores ao mapa
  for index, row in data.iterrows():
    fl.Marker([row['Latitude'], row['Longitude']], popup=row['Logradouro']).add_to(map)

  # Conectando as coordenadas
  fl.PolyLine(data[['Latitude', 'Longitude']].values, color='blue').add_to(map)

  return map

# %% [markdown]
# ## Salvar os Mapas em um Arquivo:

# %%
# # Salvando os mapas em um arquivo
# gerarMapas(sapucaia).save('map_sapucaia.html')
# gerarMapas(anta).save('map_anta.html')
# gerarMapas(aparecida).save('map_aparecida.html')
# gerarMapas(distrito).save('map_distrito.html')

# %% [markdown]
# ## Visualização dos Mapas:

# %%
# # Exibindo Sapucaia
# display(gerarMapas(sapucaia))

# %%
# # Exibindo Anta
# display(gerarMapas(anta))

# %%
# # Exibindo Aparecida
# display(gerarMapas(aparecida))

# %%
# # Exibindo Aparecida
# display(gerarMapas(distrito))

# %%
# # Exibindo Aterro - Garagem
# display(gerarMapas(garagem))

# %% [markdown]
# ## Geração do OSRM

# %%
# Gerando o link do OSRM:
# Link de exemplo: https://map.project-osrm.org/?z=17&center=-21.994312%2C-42.910903&loc=-21.994048%2C-42.915773&loc=-21.993740%2C-42.908510&hl=en&alt=0&srv=0

def gerarOSRM(data):

  # URL inicial:
  OSRM_url = 'https://map.project-osrm.org/'

  # URL Zoom:
  zoom_url = '?z=15&'

  # Definindo o centro do mapa:
  center = (data.shape[0])//2
  center_url = f'center={data.at[center, "latitude"]}%2C{data.at[center, "longitude"]}&'

  # Definindo o URL com as coordenadas:
  coord_url = ''
  for index, row in data.iterrows():
        lat, lon = row['latitude'], row['longitude']
        coord_url += (f'loc={lat}%2C{lon}&')

  # URL final:
  final_url = 'hl=en&alt=0&srv=0'

  # Montando o link:
  link = ''
  link = f'{OSRM_url}{zoom_url}{center_url}{coord_url}{final_url}'
  return link

# %%
# Gerar o link do OSRM para o Aterro-Garagem:
def gerarOSRM_garagem(data):

  # URL inicial:
  OSRM_url = 'https://map.project-osrm.org/'

  # URL Zoom:
C-42.981846226002894&loc=-22.00793572062629%2C-42.94191911461766&loc=-22.006751221522155%2C-42.93837299822342&loc=-22.007472386601396%2C-42.9379357981418&loc=-22.007569370592098%2C-42.93732559560231&loc=-22.00620420619796%2C-42.93607045830978&loc=-22.00533133949412%2C-42.93301005781208&loc=-22.005018001415017%2C-42.9323931497398&loc=-22.004640005356%2C-42.93182720366585&loc=-22.00351595846928%2C-42.931285397413525&loc=-22.00231729690728%2C-42.930365399762415&loc=-22.000014536616277%2C-42.92691959135168&loc=-22.000693500572133%2C-42.92827727206644&loc=-21.999915102267614%2C-42.92688520562066&loc=-21.99943015547337%2C-42.92715879092771&loc=-21.99924985432299%2C-42.92682887923638&loc=-21.99912799548035%2C-42.926520425210704&loc=-21.999359278498684%2C-42.92629511962975&loc=-21.99970371540541%2C-42.92604969751194&loc=-21.99909317864697%2C-42.92478503597521&loc=-21.998717264184517%2C-42.92395713373769&loc=-21.99939867955682%2C-42.92443322581 ...
# Aterro Garagem OSRM Link: https://map.project-osrm.org/?z=15&loc=-21.964026878913945%2C-42.85274167121006&loc=-22.00742412752034%2C-42.94103718221791&hl=en&alt=0&srv=0

# %% [markdown]
# # JSON

# %% [markdown]
# ## Métodos para o JSON:
#
#   - calcularCentro: Retorna o centro das coordenadas
#   - gerarJSON: Retorna o URL
#   - validarJSON: Retorna o arquivo da requisição
#   - lerJSON: Retorna a distância e o tempo total
#   - mapaJSON: Retorna o mapa gerado com as coordenadas do URL
#   - salvarJSON: Salva o arquivo obtido pelo URL do OSRM em um arquivo .json (INUTILIZADA)
#   - ArquivoVROOM: Gera e salva o arquivo que será utilizado no VROOM

# %%
# Função para calcular o centro do dataframe:
def calcularCentro(data):
  return (data['latitude'].mean(), data['longitude'].mean())

# %%
# Função para gerar o link do JSON:
def gerarJSON(data):

  # Exemplo de URL: {url_base}13.388860,52.517037;13.397634,52.529407;13.428555,52.523219?overview=false

  url_base   = 'http://router.project-osrm.org/route/v1/driving/'
  url_coords = ''
  url_final  = '?geometries=geojson&overview=full'


  # Definindo o URL com as coordenadas:
  for index, row in data.iterrows():
        lat, lon = row['latitude'], row['longitude']
        url_coords += (f'{lon},{lat};')

  # Removendo o último ponto e vírgula
  url_coords = url_coords.rstrip(';')

  url = f'{url_base}{url_coords}{url_final}'

  return url

# %%
# Função para validar se foi possível gerar corretamente o JSON
def validarJSON(data):

  url = gerarJSON(data)

  # Fazendo a solicitação HTTP
  resposta = requests.get(url)

  # Verificando se a solicitação teve sucesso
  if resposta.status_code == 200:
    dados_rota = resposta.json()
  else:
    print(f"Falha na solicitação com código de status: {resposta.status_code}")
    return

  return dados_rota

# %%
# Função para colher o campo referente à distância e à duração total da rota:
def lerJSON(data):

  dados_rota = validarJSON(data)

  # Verificando se os dados da rota foram obtidos corretamente
  if dados_rota is not None:
    # Acessando a distância do último segmento da rota
    distancia = dados_rota['routes'][0]['distance']
    duracao   = dados_rota['routes'][0]['duration']

    return distancia, duracao

# %%
# Função para gerar um novo mapa com base nas coordenadas do OSRM:
def mapaJSON(data, zoom = 14):

  # Validando a requisição
  dados_mapa = validarJSON(data)

  # Extraindo as coordenadas
  coords = dados_mapa['routes'][0]['geometry']['coordinates']

  # Invertendo as coordenadas para (lat, lon)
  coords = [(lat, lon) for lon, lat in coords]

  # Centro do mapa
  centro = calcularCentro(data)

  # Criando o Mapa
  map = fl.Map(location = centro, zoom_start= zoom)

  # Conectando as coordenadas
  fl.PolyLine(coords, color = "blue", weight=2.5, opacity=1).add_to(map)

  return map

# %%
# Função para salvar o JSON link em um arquivo .json:
# (nesta função transforma o URL obtido pelo OSRM em um arquivo .json)
def salvarJSON(data):

  url = gerarJSON(data)

  # Fazendo a requisição
  resposta = requests.get(url)

  # Verificando se a solicitação teve sucesso
  if resposta.status_code == 200:
      dados_rota = resposta.json()

      # Salva os dados em um arquivo.json
      with open(f'rota_{data.name}.json', 'w') as f:
        json.dump(dados_rota, f)

  else:
    print(f"Falha na solicitação com código de status: {resposta.status_code}")
    return

# %%
# Gerar arquivo do VROOM:
def arquivoVROOM(data):

  # Listas para os veículos e os trabalhos
  veiculos  = [] # (Inicialmente só implementarei um veículo, por hora esta lista é inútil)
  trabalhos = []

  coord_ini = [data.longitude[0], data.latitude[0]] # Posição da Garagem
  coord_fim = [data.longitude.iloc[-1], data.latitude.iloc[-1]] # Posição do Aterro Sanitário

  # Adicionar um único veículo
  veiculo = {
      "id"   : 1,
      "start": coord_ini,
      "end"  : coord_fim,
      "steps": [
          {"type": "start"}
      ]
  }

  # Adicionando os passos
  for j in range(len(data.latitude) - 1):
    veiculo["steps"].append({"type": "job", "id": j+1})
  veiculo["steps"].append({"type": "end"})

  # Adicionando o veiculo à lista de veículos
  veiculos.append(veiculo)


  # Adicionando os "jobs" para cada coordenada
  for i in range(len(data.latitude) - 1):

    coord = [data.longitude[i], data.latitude[i]]

    trabalho = {
        "id"         : i+1,
        "description": data.logradouro[i],
        "location"   : coord
    }
    trabalhos.append(trabalho)


  # Criar o objeto do VROOM
  vroom = {
      "vehicles": veiculos,
      "jobs"    : trabalhos
  }

  # Salvar os dados em um arquivo
  with open(f'VROOM_{data.name}.json', 'w') as f:
    json.dump(vroom, f, indent = 2)

# %% [markdown]
# ## Exibindo os links de cada JSON:

# %%
print("Sapucaia JSON Link: ", gerarJSON(sapucaia))
print("Anta JSON Link: ", gerarJSON(anta))
print("Aparecida JSON Link: ", gerarJSON(aparecida))
print("Garagem JSON Link: ", gerarJSON(garagem))
# Out:
# Sapucaia JSON Link:  http://router.project-osrm.org/route/v1/driving/-42.94103718221791,-22.00742412752034;-42.941422025172,-22.00733048407398;-42.94223293310388,-22.007565192648723;-42.94191911461766,-22.00793572062629;-42.93963113729489,-22.00734847235366;-42.938493697639466,-22.00670272925291;-42.93837299822342,-22.006751221522155;-42.9379357981418,-22.007472386601396;-42.93732559560231,-22.007569370592098;-42.93607045830978,-22.00620420619796;-42.93322731674584,-22.005378588825653;-42.93301005781208,-22.00533133949412;-42.9323931497398,-22.005018001
# Garagem JSON Link:  http://router.project-osrm.org/route/v1/driving/-42.85274167121006,-21.964026878913945;-42.94103718221791,-22.00742412752034?geometries=geojson&overview=full

# %%
# Definindo os nomes dos Dataframes:
sapucaia.name  = "Sapucaia"
anta.name      = "Anta"
aparecida.name = "Aparecida"
distrito.name  = "Distrito"
garagem.name   = "Garagem"

# Gerando os arquivos .json
arquivoVROOM(sapucaia)
arquivoVROOM(anta)
arquivoVROOM(aparecida)
arquivoVROOM(distrito)
arquivoVROOM(garagem)

# %% [markdown]
# ## Visualização dos mapas:

# %%
# Visualização Mapa de Sapucaia
display(mapaJSON(sapucaia))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4adc68267a332e3429be39ece6eb0986 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4adc68267a332e3429be39ece6eb0986&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4adc68267a332e3429be39ece6eb0986 = L.map(
#                 &quot;map_4adc68267a332e3429be39ece6eb0986&quot;,
#                 {
#                     center: [-21.997709004826383, -42.920359692939584],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84dbda0c057631e71207b8870f609db0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4adc68267a332e3429be39ece6eb0986);
#
#
#             var poly_line_ec6dc212380e58314d2438791e38f265 = L.polyline(
#                 [[-22.007204, -42.941107], [-22.007293, -42.941434], [-22.007466, -42.94207], [-22.007527, -42.942252], [-22.007565, -42.942251], [-22.007788, -42.942247], [-22.007906, -42.942249], [-22.007875, -42.941926], [-22.00781, -42.941238], [-22.00775, -42.940894], [-22.007733, -42.940804], [-22.007605, -42.940348], [-22.007531, -42.940125], [-22.00738, -42.939774], [-22.007314, -42.939652], [-22.006691, -42.938502], [-22.006666, -42.938456], [-22.006764, -42.9384], [-22.007028, -42.93825], [-22.00749, -42.93797], [-22.007494, -42.937967], [-22.007561, -42.937922], [-22.007589, -42.937882], [-22.007601, -42.937839], [-22.007601, -42.937781], [-22.00758, -42.937661], [-22.007579, -42.937595], [-22.00759, -42.937538], [-22.007622, -42.937426], [-22.007574, -42.937323], [-22.007473, -42.937104], [-22.007379, -42.936993], [-22.007265, -42.936892], [-22.006972, -42.936706], [-22.00677, -42.93654], [-22.00629, -42.936113], [-22.006216, -42.936053], [-22.005945, -42.93583], [-22.005772, -42.935664], [-22.005696, -42.935564], [-22.00565, -42.935448], [-22.005587, -42.935189], [-22.005546, -42.93497], [-22.005531, -42.934849], [-22.005545, -42.934725], [-22.005576, -42.934607], [-22.005605, -42.934514], [-22.005616, -42.934432], [-22.005614, -42.934319], [-22.005571, -42.933946], [-22.005542, -42.933864], [-22.005484, -42.933772], [-22.005412, -42.933631], [-22.005386, -42.933553], [-22.005367, -42.933398], [-22.005376, -42.933276], [-22.005379, -42.933227], [-22.005383, -42.933165], [-22.005316, -42.933018], [-22.005063, -42.932467], [-22.005023, -42.93239], [-22.004762, -42.931889], [-22.004717, -42.931803], [-22.004655, -42.93185], [-22.004521, -42.93195], [-22.004251, -42.932103], [-22.004074, -42.932191], [-22.004021, -42.932119], [-22
# Para efeito de comparação após rodar o vroom a distância obtida foi de 21 km
# Out:
# A distância do percurso de Sapucaia é de 34650.3 metros ou 34.65 km.
# A duração do percurso de Sapucaia é de 2474.1 segundos ou 41.23 minutos.

# %%
anta_distancia, anta_duracao = lerJSON(anta)
anta_distancia += garagem_distancia

print(f"A distância do percurso de Anta é de {anta_distancia} metros ou {anta_distancia/1000:.2f} km.")
print(f"A duração do percurso de Anta é de {anta_duracao} segundos ou {anta_duracao/60:.2f} minutos.")

# Para efeito de comparação após rodar o vroom a distância obtida foi de 34,9 km
# Out:
# A distância do percurso de Anta é de 52745.399999999005 metros ou 52.75 km.
# A duração do percurso de Anta é de 3982.3 segundos ou 66.37 minutos.

# %%
distrito_distancia, distrito_duracao = lerJSON(distrito)

print(f"A distância do percurso do Distrito é de {distrito_distancia} metros ou {distrito_distancia/1000:.2f} km.")
print(f"A duração do percurso do Distrito é de {distrito_duracao} segundos ou {distrito_duracao/60:.2f} minutos.")
# Out:
# A distância do percurso do Distrito é de 106167.2 metros ou 106.17 km.
# A duração do percurso do Distrito é de 11171.1 segundos ou 186.19 minutos.

# %%
aparecida_distancia, aparecida_duracao = lerJSON(aparecida)
aparecida_distancia += garagem_distancia

print(f"A distância do percurso de Aparecida é de {aparecida_distancia} metros ou {aparecida_distancia/1000:.2f} km.")
print(f"A duração do percurso de Aparecida é de {aparecida_duracao} segundos ou {aparecida_duracao/60:.2f} minutos.")

# Para efeito de comparação após rodar o vroom a distância obtida foi de 52,4 km
# Out:
# A distância do percurso de Aparecida é de 81073.90000000001 metros ou 81.07 km.
# A duração do percurso de Aparecida é de 6511.099999999 segundos ou 108.52 minutos.

# %%
# Distancia do percurso total já considerando a volta do Aterro para a Garagem:
dist_total = (sapucaia_distancia + aparecida_distancia + anta_distancia)

print(f"A distância total do percurso é de {dist_total:.2f} metros ou {dist_total/1000:.2f} km.")
# Out:
# A distância total do percurso é de 168469.60 metros ou 168.47 km.

# %% [markdown]
# ## Cálculo dos Custos com a Rota Original:

# %%
# Função para calcular os custos com a economia de combustível:
# Considerar 6 dias para Sapucaia e Anta e 3 dias para Aparecida
def calcular_custos(distancia, consumo, preco_combustivel, vezes_na_semana = 6):
    diario = ((distancia/1000)/consumo)*preco_combustivel
    semanal = diario * vezes_na_semana
    mensal = semanal * 4
    anual = mensal * 12
    return diario, semanal, mensal, anual


def imprimir_custos(custos):
    for index, row in custos.iterrows():
        print(f"ROTA -> {row['rota']} - Consumo de {row['consumo de combustivel']} km/L")
        print(f"Distância considerada de {row['distancia']/1000:.2f} km\n")
        print(f"1 Dia: R${row['custo diario']:.2f}")
        print(f"1 Semana (Considerando 6 dias/sem): R${row['custo semanal']:.2f}")
        print(f"1 Mês (4 semanas): R${row['custo mensal']:.2f}")
        print(f"1 Ano: R${row['custo anual']:.2f}\n")
        print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - \n")

# %%
# Criando um dataframe para armazenar todos os custos que serão calculados:
custos = pd.DataFrame(columns = ['rota', 'distancia', 'consumo de combustivel', 'preco combustivel', 'custo diario', 'custo semanal', 'custo mensal', 'custo anual'])

# %%
# Valor do Litro de Diesel S10 no Estado do Rio de Janeiro segundo a ANP:
combustivel = 6.02

# Valor da distância total percorrida (Rota Original):
# dist_total

# Valor da distância total percorrida (Rota Otimizada com 1 Caminhão):
# Resultados com otimziação de 1 caminhão:
# Distância de Sapucaia:   21.0 km
# Distância de Aparecida:  52.4 km
# Distância de Anta:       34.9 km
# + Distância do Aterro-Garagem: 3 * $garagem_distancia

dist_1caminhao = 21*1000 + 52.4*1000 + 34.9*1000 + 3*garagem_distancia

distancias = {'original': dist_total, 'otimizada - 1 caminhao': dist_1caminhao}
consumos = [3.0, 3.5, 4.0]

for rota, distancia in distancias.items():
  for consumo in consumos:
    # Calculando os custos:
    diario, semanal, mensal, anual = calcular_custos(distancia, consumo, combustivel)

    # Atribuindo ao DataFrame 'custos':
    novo_custo = pd.DataFrame({
        'rota': [rota],
        'distancia': [distancia],
        'consumo de combustivel': [consumo],
        'preco combustivel': [combustivel],
        'custo diario': [diario],
        'custo semanal': [semanal],
        'custo mensal': [mensal],
        'custo anual': [anual]
    })
    custos = pd.concat([custos, novo_custo], ignore_index=True)

custos
# Out:
#                      rota  distancia  consumo de combustivel  \
# 0                original   168469.6                     3.0
# 1                original   168469.6                     3.5
# 2                original   168469.6                     4.0
# 3  otimizada - 1 caminhao   144857.4                     3.0
# 4  otimizada - 1 caminhao   144857.4                     3.5
# 5  otimizada - 1 caminhao   144857.4                     4.0
#
#    preco combustivel  custo diario  custo semanal  custo mensal   custo anual
# 0               6.02    338.062331    2028.373984   8113.495936  97361.951232
# 1               6.02    289.767712    1738.606272   6954.425088  83453.101056
# 2               6.02    253.546748    1521.280488   6085.121952  73021.463424
# 3               6.02    290.680516    1744.083096   6976.332384  83715.988608
# 4               6.02    249.154728    1494.928368   5979.713472  71756.561664
# 5               6.02    218.010387    1308.062322   5232.249288  62786.991456

# %%
#Impressão dos custos
imprimir_custos(custos)
# Out:
# ROTA -> original - Consumo de 3.0 km/L
# Distância considerada de 168.47 km
#
# 1 Dia: R$338.06
# 1 Semana (Considerando 6 dias/sem): R$2028.37
# 1 Mês (4 semanas): R$8113.50
# 1 Ano: R$97361.95
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ROTA -> original - Consumo de 3.5 km/L
# Distância considerada de 168.47 km
#
# 1 Dia: R$289.77
# 1 Semana (Considerando 6 dias/sem): R$1738.61
# 1 Mês (4 semanas): R$6954.43
# 1 Ano: R$83453.10
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ROTA -> original - Consumo de 4.0 km/L
# Distância considerada de 168.47 km
#
# 1 Dia: R$253.55
# 1 Semana (Considerando 6 dias/sem): R$1521.28
# 1 Mês (4 semanas): R$6085.12
# 1 Ano: R$73021.46
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ROTA -> otimizada - 1 caminhao - Consumo de 3.0 km/L
# Distância considerada de 144.86 km
#
# 1 Dia: R$290.68
# 1 Semana (Considerando 6 dias/sem): R$1744.08
# 1 Mês (4 semanas): R$6976.33
# 1 Ano: R$83715.99
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ROTA -> otimizada - 1 caminhao - Consumo de 3.5 km/L
# Distância considerada de 144.86 km
#
# 1 Dia: R$249.15
# 1 Semana (Considerando 6 dias/sem): R$1494.93
# 1 Mês (4 semanas): R$5979.71
# 1 Ano: R$71756.56
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ROTA -> otimizada - 1 caminhao - Consumo de 4.0 km/L
# Distância considerada de 144.86 km
#
# 1 Dia: R$218.01
# 1 Semana (Considerando 6 dias/sem): R$1308.06
# 1 Mês (4 semanas): R$5232.25
# 1 Ano: R$62786.99
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
# Valor do Litro de Diesel S10 no Estado do Rio de Janeiro segundo a ANP:
combustivel = 6.02

# Variaveis
dia_orig_3 = ((dist_total/1000)/3)*combustivel
sem_orig_3 = dia_orig_3 * 6
mes_orig_3 = sem_orig_3 * 4
ano_orig_3 = mes_orig_3 * 12

dia_orig_3_5 = ((dist_total/1000)/3.5)*combustivel
sem_orig_3_5 = dia_orig_3_5 * 6
mes_orig_3_5 = sem_orig_3_5 * 4
ano_orig_3_5 = mes_orig_3_5 * 12

dia_orig_4 = ((dist_total/1000)/4)*combustivel
sem_orig_4 = dia_orig_4 * 6
mes_orig_4 = sem_orig_4 * 4
ano_orig_4 = mes_orig_4 * 12


print("CUSTOS -> ROTA ORIGINAL:")
print(f"Distância considerada de {dist_total/1000:.2f} km\n")
print("Considerando o consumo de 3 km/L:")
print(f"1 Dia:                              R${dia_orig_3:.2f}")
print(f"1 Semana (Considerando 6 dias/sem): R${sem_orig_3:.2f}")
print(f"1 Mês (4 semanas):                  R${mes_orig_3:.2f}")
print(f"1 Ano:                              R${ano_orig_3:.2f}")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print("Considerando o consumo de 3.5 km/L:")
print(f"1 Dia:                              R${dia_orig_3_5:.2f}")
print(f"1 Semana (Considerando 6 dias/sem): R${sem_orig_3_5:.2f}")
print(f"1 Mês (4 semanas):                  R${mes_orig_3_5:.2f}")
print(f"1 Ano:                              R${ano_orig_3_5:.2f}")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print("Considerando o consumo de 4 km/L:")
print(f"1 Dia:                              R${dia_orig_4:.2f}")
print(f"1 Semana (Considerando 6 dias/sem): R${sem_orig_4:.2f}")
print(f"1 Mês (4 semanas):                  R${mes_orig_4:.2f}")
print(f"1 Ano:                              R${ano_orig_4:.2f}")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")

# Resultados com otimziação de 1 caminhão:
# Distância de Sapucaia:   21.0 km
# Distância de Aparecida:  52.4 km
# Distância de Anta:       34.9 km
# + Distância do Aterro-Garagem: 3 * $garagem_distancia

dist_1caminhao = 21*1000 + 52.4*1000 + 34.9*1000 + 3*garagem_distancia

dia_1caminhao_3 = ((dist_1caminhao/1000)/3)*combustivel
sem_1caminhao_3 = dia_1caminhao_3 * 6
mes_1caminhao_3 = sem_1caminhao_3 * 4
ano_1caminhao_3 = mes_1caminhao_3 * 12

dia_1caminhao_3_5 = ((dist_1caminhao/1000)/3.5)*combustivel
sem_1caminhao_3_5 = dia_1caminhao_3_5 * 6
mes_1caminhao_3_5 = sem_1caminhao_3_5 * 4
ano_1caminhao_3_5 = mes_1caminhao_3_5 * 12

dia_1caminhao_4 = ((dist_1caminhao/1000)/4)*combustivel
sem_1caminhao_4 = dia_1caminhao_4 * 6
mes_1caminhao_4 = sem_1caminhao_4 * 4
ano_1caminhao_4 = mes_1caminhao_4 * 12


print("\nCUSTOS -> ROTA OTIMIZADA - 1 Caminhão:")
print(f"Distância considerada de {dist_1caminhao/1000:.2f} km\n")
print("Considerando o consumo de 3 km/L:")
print(f"1 Dia:                              R${dia_1caminhao_3:.2f}       Economia gerada de R$ {(dia_orig_3 - dia_1caminhao_3):.2f} ({(1-(dia_1caminhao_3/dia_orig_3))*100:.2f}%)")
print(f"1 Semana (Considerando 6 dias/sem): R${sem_1caminhao_3:.2f}      Economia gerada de R$ {(sem_orig_3 - sem_1caminhao_3):.2f}")
print(f"1 Mês (4 semanas):                  R${mes_1caminhao_3:.2f}      Economia gerada de R$ {(mes_orig_3 - mes_1caminhao_3):.2f}")
print(f"1 Ano:                              R${ano_1caminhao_3:.2f}     Economia gerada de R$ {(ano_orig_3 - ano_1caminhao_3):.2f}")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print("Considerando o consumo de 3.5 km/L:")
print(f"1 Dia:                              R${dia_1caminhao_3_5:.2f}       Economia gerada de R$ {(dia_orig_3_5 - dia_1caminhao_3_5):.2f} ({(1-(dia_1caminhao_3_5/dia_orig_3_5))*100:.2f}%)")
print(f"1 Semana (Considerando 6 dias/sem): R${sem_1caminhao_3_5:.2f}      Economia gerada de R$ {(sem_orig_3_5 - sem_1caminhao_3_5):.2f}")
print(f"1 Mês (4 semanas):                  R${mes_1caminhao_3_5:.2f}      Economia gerada de R$ {(mes_orig_3_5 - mes_1caminhao_3_5):.2f}")
print(f"1 Ano:                              R${ano_1caminhao_3_5:.2f}     Economia gerada de R$ {(ano_orig_3_5 - ano_1caminhao_3_5):.2f}")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print("Considerando o consumo de 4 km/L:")
print(f"1 Dia:                              R${dia_1caminhao_4:.2f}       Economia gerada de R$ {(dia_orig_4 - dia_1caminhao_4):.2f} ({(1-(dia_1caminhao_4/dia_orig_4))*100:.2f}%)")
print(f"1 Semana (Considerando 6 dias/sem): R${sem_1caminhao_4:.2f}      Economia gerada de R$ {(sem_orig_4 - sem_1caminhao_4):.2f}")
print(f"1 Mês (4 semanas):                  R${mes_1caminhao_4:.2f}      Economia gerada de R$ {(mes_orig_4 - mes_1caminhao_4):.2f}")
print(f"1 Ano:                              R${ano_1caminhao_4:.2f}     Economia gerada de R$ {(ano_orig_4 - ano_1caminhao_4):.2f}")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
# Out:
# CUSTOS -> ROTA ORIGINAL:
# Distância considerada de 168.47 km
#
# Considerando o consumo de 3 km/L:
# 1 Dia:                              R$338.06
# 1 Semana (Considerando 6 dias/sem): R$2028.37
# 1 Mês (4 semanas):                  R$8113.50
# 1 Ano:                              R$97361.95
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Considerando o consumo de 3.5 km/L:
# 1 Dia:                              R$289.77
# 1 Semana (Considerando 6 dias/sem): R$1738.61
# 1 Mês (4 semanas):                  R$6954.43
# 1 Ano:                              R$83453.10
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Considerando o consumo de 4 km/L:
# 1 Dia:                              R$253.55
# 1 Semana (Considerando 6 dias/sem): R$1521.28
# 1 Mês (4 semanas):                  R$6085.12
# 1 Ano:                              R$73021.46
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# CUSTOS -> ROTA OTIMIZADA - 1 Caminhão:
# Distância considerada de 144.86 km
#
# Considerando o consumo de 3 km/L:
# 1 Dia:                              R$290.68       Economia gerada de R$ 47.38 (14.02%)
# 1 Semana (Considerando 6 dias/sem): R$1744.08      Economia gerada de R$ 284.29
# 1 Mês (4 semanas):                  R$6976.33      Economia gerada de R$ 1137.16
# 1 Ano:                              R$83715.99     Economia gerada de R$ 13645.96
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Considerando o consumo de 3.5 km/L:
# 1 Dia:                              R$249.15       Economia gerada de R$ 40.61 (14.02%)
# 1 Semana (Considerando 6 dias/sem): R$1494.93      Economia gerada de R$ 243.68
# 1 Mês (4 semanas):                  R$5979.71      Economia gerada de R$ 974.71
# 1 Ano:                              R$71756.56     Economia gerada de R$ 11696.54
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Considerando o consumo de 4 km/L:
# 1 Dia:                              R$218.01       Economia gerada de R$ 35.54 (14.02%)
# 1 Semana (Considerando 6 dias/sem): R$1308.06      Economia gerada de R$ 213.22
# 1 Mês (4 semanas):                  R$5232.25      Economia gerada de R$ 852.87
# 1 Ano:                              R$62786.99     Economia gerada de R$ 10234.47
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# # API Carbon Interface:

# %%
# # Calcular a quantidade de galôes para a API:

# # Taxa para a conversão de litros para galões
# tx_galao =  3.78541

# # Quantidade de litros nas rotas Atuais:
# litros_orig_3   = (ano_orig_3/combustivel)/tx_galao
# litros_orig_3_5 = (ano_orig_3_5/combustivel)/tx_galao
# litros_orig_4   = (ano_orig_4/combustivel)/tx_galao

# # Quantidades de litros nas rotas otimizadas:
# litros_1caminhao_3   = (ano_1caminhao_3/combustivel)/tx_galao
# litros_1caminhao_3_5 = (ano_1caminhao_3_5/combustivel)/tx_galao
# litros_1caminhao_4   = (ano_1caminhao_4/combustivel)/tx_galao

# print(litros_orig_3)
# print(litros_orig_3_5)
# print(litros_orig_4)
# print(litros_1caminhao_3)
# print(litros_1caminhao_3_5)
# print(litros_1caminhao_4)

# %%
# url = "https://www.carboninterface.com/api/v1/estimates"

# headers = {
#     'Authorization': 'Bearer 8ghXwBkzlc4xlnLQTcIEFA',
#     'Content-Type': 'application/json'
# }

# %%
# data_orig_3 = {
#       "name": "Otimização - 1 Caminhão - 3.5 km/l",
#       "type": "fuel_combustion",
#       "fuel_source_type": "dfo",
#       "fuel_source_unit": "gallon",
#       "fuel_source_value": litros_orig_3
# }

# data_orig_3_5 = {
#       "type": "fuel_combustion",
#       "fuel_source_type": "dfo",
#       "fuel_source_unit": "gallon",
#       "fuel_source_value": litros_orig_3_5
# }

# data_orig_4 = {
#       "type": "fuel_combustion",
#       "fuel_source_type": "dfo",
#       "fuel_source_unit": "gallon",
#       "fuel_source_value": litros_orig_4
# }

# data_1caminhao_3 = {
#       "type": "fuel_combustion",
#       "fuel_source_type": "dfo",
#       "fuel_source_unit": "gallon",
#       "fuel_source_value": litros_1caminhao_3
# }

# data_1caminhao_3_5 = {
#       "name": "Otimização - 1 Caminhão - 3.5 km/l",
#       "type": "fuel_combustion",
#       "fuel_source_type": "dfo",
#       "fuel_source_unit": "gallon",
#       "fuel_source_value": litros_1caminhao_3_5
# }

# data_1caminhao_4 = {
#       "type": "fuel_combustion",
#       "fuel_source_type": "dfo",
#       "fuel_source_unit": "gallon",
#       "fuel_source_value": litros_1caminhao_4
# }

# %%
# # Requisições da Emissão da Rota Original
# response_orig_3   = requests.post(url, headers=headers, json=data_orig_3)
# response_orig_3_5 = requests.post(url, headers=headers, json=data_orig_3_5)
# response_orig_4   = requests.post(url, headers=headers, json=data_orig_4)

# # Requisições da Emissão da Rota Otimizada 1 Caminhão
# response_1caminhao_3   = requests.post(url, headers=headers, json=data_1caminhao_3)
# response_1caminhao_3_5 = requests.post(url, headers=headers, json=data_1caminhao_3_5)
# response_1caminhao_4   = requests.post(url, headers=headers, json=data_1caminhao_4)

# %%
# # Impressões das Emissões da Rota Original Variando o Consumo

# carbon_data_orig_3   = response_orig_3.json()
# carbon_data_orig_3_5 = response_orig_3_5.json()
# carbon_data_orig_4   = response_orig_4.json()

# print(f"Emissão de Carbono da Rota Original - Consumo 3 km/L")
# print(json.dumps(carbon_data_orig_3, indent = 4))
# print("\n\n\n")

# print(f"Emissão de Carbono da Rota Original - Consumo 3.5 km/L")
# print(json.dumps(carbon_data_orig_3_5, indent = 4))
# print("\n\n\n")

# print(f"Emissão de Carbono da Rota Original - Consumo 4 km/L")
# print(json.dumps(carbon_data_orig_4, indent = 4))
# print("\n\n\n")

# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# # Impressões das Emissões da Rota Otimizada com 1 Caminhão Variando o Consumo

# carbon_data_1caminhao_3   = response_1caminhao_3.json()
# carbon_data_1caminhao_3_5 = response_1caminhao_3_5.json()
# carbon_data_1caminhao_4   = response_1caminhao_4.json()

# print(f"Emissão de Carbono da Rota Original - Consumo 3 km/L")
# print(json.dumps(carbon_data_1caminhao_3, indent = 4))
# print("\n\n\n")

# print(f"Emissão de Carbono da Rota Original - Consumo 3.5 km/L")
# print(json.dumps(carbon_data_1caminhao_3_5, indent = 4))
# print("\n\n\n")

# print(f"Emissão de Carbono da Rota Original - Consumo 4 km/L")
# print(json.dumps(carbon_data_1caminhao_4, indent = 4))
# print("\n\n\n")

# %%
# carbon_kg = carbon_data_orig_3['data']['attributes']['carbon_kg']
# print(f'A quantidade de carbono emitida é {carbon_kg} kg')

# %%
# Tentativa de encontrar o modelo do caminhão Fracassada

# #Url para verificar o id das fabricantes:
# url = "https://www.carboninterface.com/api/v1/vehicle_makes"

# #Url para verificar o modelo do veículo:
# url = "https://www.carboninterface.com/api/v1/vehicle_makes/eaca7ef3-19e0-47f5-84d8-bb78c6bde5d2/vehicle_models"

# # Volksvagen = 86e1e7df-57c2-4753-9f7f-c1a2a1529942
# # Ford = 647f3fec-9a31-48c8-acc2-359f39cc3122
# # Mercedes-Benz = eaca7ef3-19e0-47f5-84d8-bb78c6bde5d2

# resp = requests.get(url, headers=headers, json=data)

# veiculos = resp.json()
# veiculos
